# %% [markdown]
# # 🤖📚 Machine Learning
#
#
# ## Apa itu Machine Learning 🔎❓
#
#
# * ➡️  Suatu cabang ilmu yang memberi komputer kemampuan untuk belajar tanpa diprogram secara eksplisit
# * ➡️  Machine Learning termasuk dalam ilmu Artificial Intelligence
# * ➡️  Machine Learning menjadi evolusi dari pemrograman tradisional
#
#
# ### Referensi
#
#
# *  Sumber : Dicoding
# *  Kursus : Belajar Machine Learning untuk Pemula
